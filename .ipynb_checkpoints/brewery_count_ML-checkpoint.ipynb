# %%
from sklearn import tree
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join("rg_proj2_resources/countydemographicsFINALPROJwithbrewcount.csv"))
df.head()
# Out:
#    fips_txt Stabr                 area_name  countbrewpub  countcontract  \
# 0      8111    CO       San Juan County, CO             2              0
# 1      2230    AK  Skagway Municipality, AK             2              0
# 2     35021    NM        Harding County, NM             0              0
# 3      8053    CO       Hinsdale County, CO             1              0
# 4      8091    CO          Ouray County, CO             3              0
#
#    countmicro  countregional  counttotal  countlargest  countbest  ...  \
# 0           0              0           2             0          0  ...
# 1           0              0           2             0          0  ...
# 2           1              0           1             0          0  ...
# 3           0              0           1             0          0  ...
# 4           1              0           4             0          0  ...
#
#    regionalper10000  breweriesTOTALper10000  largestboolean  bestboolean  \
# 0               0.0               27.472527           False        False
# 1               0.0               16.906171           False        False
# 2               0.0               16.000000           False        False
# 3               0.0               12.195122           False        False
# 4               0.0                8.077544           False        False
#
#    median_HHI_2019  bach_deg_pct_14to18  Latitude   Longitude  population2019  \
# 0            50524                 34.5  37.78108 -107.670257             728
# 1            74898                 33.7  59.57510 -135.335418            1183
# 2            38162                 24.3  35.86315 -103.829931             625
# 3            61391                 43.9  37.81163 -107.383405             820
# 4            72836                 48.6  38.15060 -107.767133            4952
#
#             countyshort
# 0              San Juan
# 1  Skagway Municipality
# 2               Harding
# 3              Hinsdale
# 4                 Ouray
#
# [5 rows x 23 columns]

# %%
df_sample = df.sample(frac=0.25)
df_sample
# Out:
#       fips_txt Stabr             area_name  countbrewpub  countcontract  \
# 3066     53021    WA   Franklin County, WA             0              0
# 2438     37155    NC    Robeson County, NC             0              0
# 2390     35005    NM     Chaves County, NM             0              0
# 404       6073    CA  San Diego County, CA            37              2
# 1957     21159    KY     Martin County, KY             0              0
# ...        ...   ...                   ...           ...            ...
# 215      51735    VA     Poquoson city, VA             0              0
# 819      27061    MN     Itasca County, MN             0              0
# 2777     47173    TN      Union County, TN             0              0
# 2418     37017    NC     Bladen County, NC             0              0
# 2318     31045    NE      Dawes County, NE             0              0
#
#       countmicro  countregional  counttotal  countlargest  countbest  ...  \
# 3066           0              0           0             0          0  ...
# 2438           0              0           0             0          0  ...
# 2390           0              0           0             0          0  ...
# 404           94              9         159             3          7  ...
# 1957           0              0           0             0          0  ...
# ...          ...            ...         ...           ...        ...  ...
# 215            0              0           1             0          0  ...
# 819            1              0           1             0          0  ...
# 2777           0              0           0             0          0  ...
# 2418           0              0           0             0          0  ...
# 2318           0              0           0             0          0  ...
#
#       regionalper10000  breweriesTOTALper10000  largestboolean  bestboolean  \
# 3066           0.00000                0.000000           False        False
# 2438           0.00000                0.000000           False        False
# 2390           0.00000                0.000000           False        False
# 404            0.02696                0.476286            True         True
# 1957           0.00000                0.000000           False        False
# ...                ...                     ...             ...          ...
# 215            0.00000                0.814930           False        False
# 819            0.00000                0.221582           False        False
# 2777           0.00000                0.000000           False        False
# 2418           0.00000                0.000000           False        False
# 2318           0.00000                0.000000           False        False
#
#       median_HHI_2019  bach_deg_pct_14to18  Latitude   Longitude  \
# 3066            63575                 17.3  46.53458 -118.906944
# 2438            36366                 13.2  34.63921  -79.100881
# 2390            43687                 17.8  33.36161 -104.469837
# 404             83576                 38.1  33.02360 -116.776117
# 1957            34291                  8.5  37.79677  -82.506623
# ...               ...                  ...       ...         ...
# 215             98217                 42.8  37.12836  -76.303534
# 819             58660                 22.7  47.49084  -93.613128
# 2777            48106                  8.5  36.28414  -83.836088
# 2418            42260                 15.1  34.59195  -78.539513
# 2318            46377                 37.0  42.71121 -103.134872
#
#       population2019    countyshort
# 3066           95222       Franklin
# 2438          130625        Robeson
# 2390           64615         Chaves
# 404          3338330      San Diego
# 1957           11195         Martin
# ...              ...            ...
# 215            12271  Poquoson city
# 819            45130         Itasca
# 2777           19972          Union
# 2418           32722         Bladen
# 2318            8589          Dawes
#
# [785 rows x 23 columns]

# %%
target = df_sample["breweriesTOTALper10000"]
df_sample.columns
# Out:
# Index(['fips_txt', 'Stabr', 'area_name', 'countbrewpub', 'countcontract',
#        'countmicro', 'countregional', 'counttotal', 'countlargest',
#        'countbest', 'brewpubper10000', 'contractper10000', 'microper10000',
#        'regionalper10000', 'breweriesTOTALper10000', 'largestboolean',
#        'bestboolean', 'median_HHI_2019', 'bach_deg_pct_14to18', 'Latitude',
#        'Longitude', 'population2019', 'countyshort'],
#       dtype='object')

# %%
data = df_sample[['median_HHI_2019', 'bach_deg_pct_14to18','population2019']]
data.head()
# Out:
#       median_HHI_2019  bach_deg_pct_14to18  population2019
# 3066            63575                 17.3           95222
# 2438            36366                 13.2          130625
# 2390            43687                 17.8           64615
# 404             83576                 38.1         3338330
# 1957            34291                  8.5           11195

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
from sklearn.model_selection import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-8291e68a93f3> in <module>
# ----> 1 from sklearn.model_selection import RandomForestClassifier
#       2 rf = RandomForestClassifier(n_estimators=200)
#       3 rf = rf.fit(X_train, y_train)
#       4 rf.score(X_test, y_test)
#
# ImportError: cannot import name 'RandomForestClassifier' from 'sklearn.model_selection' (C:\Users\regro\anaconda3\lib\site-packages\sklearn\model_selection\__init__.py)

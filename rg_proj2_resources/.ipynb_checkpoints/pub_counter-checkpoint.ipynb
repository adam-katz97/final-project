# %%
import pandas as pd

# %%
brew_path = "breweries_FINALPROJv2.csv"
county_path = "countydemographicsv1latlong.csv"
brew_df = pd.read_csv(brew_path)
county_df = pd.read_csv(county_path)
brew_df
# Out:
#       Unnamed: 0  Unnamed: 0.1               BreweryName BreweryType  \
# 0              0             0       Avondale Brewing Co       micro
# 1              1             1          Trim Tab Brewing       micro
# 2              2             2      Yellowhammer Brewery       micro
# 3              3             3  Bearpaw River Brewing Co       micro
# 4              4             4    King Street Brewing Co       micro
# ...          ...           ...                       ...         ...
# 6682        6682          6682   Public Craft Brewing Co       micro
# 6683        6683          6683     Stevens Point Brewery    regional
# 6684        6684          6684      Titletown Brewing Co     brewpub
# 6685        6685          6685    Black Tooth Brewing Co       micro
# 6686        6686          6686  Gillette Brewing Company     brewpub
#
#        Latitude   Longitude             County State  CountyID  LargestList  \
# 0     33.524521  -86.774322          Jefferson    AL      1073        False
# 1     33.512849  -86.791400          Jefferson    AL      1073        False
# 2     34.727752  -86.593201            Madison    AL      1089        False
# 3     61.575269 -149.412710  Matanuska-Susitna    AK      2170        False
# 4     61.138489 -149.879076          Anchorage    AK      2020        False
# ...         ...         ...                ...   ...       ...          ...
# 6682  42.583154  -87.819751            Kenosha    WI     55059        False
# 6683  44.510263  -89.573981            Portage    WI     55097         True
# 6684  44.518920  -88.018517              Brown    WI     55009        False
# 6685  44.800895 -106.953506           Sheridan    WY     56033        False
# 6686  44.292038 -105.503614           Campbell    WY     56005        False
#
#       BestList
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ...        ...
# 6682     False
# 6683     False
# 6684     False
# 6685     False
# 6686     False
#
# [6687 rows x 11 columns]

# %%
grouped_df=brew_df.groupby(["CountyID"]).size().reset_index(name='Brewery_Count')
grouped_df
# Out:
#       CountyID  Brewery_Count
# 0         1003              3
# 1         1015              1
# 2         1055              1
# 3         1071              1
# 4         1073              9
# ...        ...            ...
# 1280     56029              3
# 1281     56033              3
# 1282     56037              2
# 1283     56039              4
# 1284     56041              1
#
# [1285 rows x 2 columns]

# %%
grouped_df = grouped_df.rename(columns={"CountyID":"fips_txt"})
grouped_df
# Out:
#       fips_txt  Brewery_Count
# 0         1003              3
# 1         1015              1
# 2         1055              1
# 3         1071              1
# 4         1073              9
# ...        ...            ...
# 1280     56029              3
# 1281     56033              3
# 1282     56037              2
# 1283     56039              4
# 1284     56041              1
#
# [1285 rows x 2 columns]

# %%
merged_df = pd.merge(county_df, grouped_df, how="outer")
merged_df
# Out:
#       fips_txt Stabr            area_name  median_HHI_2019  \
# 0         1001    AL   Autauga County, AL          58233.0
# 1         1003    AL   Baldwin County, AL          59871.0
# 2         1005    AL   Barbour County, AL          35972.0
# 3         1007    AL      Bibb County, AL          47918.0
# 4         1009    AL    Blount County, AL          52902.0
# ...        ...   ...                  ...              ...
# 3136     56039    WY     Teton County, WY          98837.0
# 3137     56041    WY     Uinta County, WY          70756.0
# 3138     56043    WY  Washakie County, WY          55122.0
# 3139     56045    WY    Weston County, WY          59410.0
# 3140      2063   NaN                  NaN              NaN
#
#       bach_deg_pct_14to18  Latitude   Longitude  population2019  Brewery_Count
# 0                    27.7  32.53638  -86.644490         55869.0            NaN
# 1                    31.3  30.65922  -87.746067        223234.0            3.0
# 2                    12.2  31.87067  -85.405456         24686.0            NaN
# 3                    11.5  33.01589  -87.127148         22394.0            NaN
# 4                    12.6  33.97745  -86.567246         57826.0            NaN
# ...                   ...       ...         ...             ...            ...
# 3136                 57.4  44.04932 -110.588102         23464.0            4.0
# 3137                 15.4  41.28473 -110.558947         20226.0            1.0
# 3138                 21.5  43.87883 -107.669052          7805.0            NaN
# 3139                 19.2  43.84621 -104.570020          6927.0            NaN
# 3140                  NaN       NaN         NaN             NaN            1.0
#
# [3141 rows x 9 columns]

# %%
merged_df["Brewery_Count"] = merged_df["Brewery_Count"].fillna(0)
merged_df
# Out:
#       fips_txt Stabr            area_name  median_HHI_2019  \
# 0         1001    AL   Autauga County, AL          58233.0
# 1         1003    AL   Baldwin County, AL          59871.0
# 2         1005    AL   Barbour County, AL          35972.0
# 3         1007    AL      Bibb County, AL          47918.0
# 4         1009    AL    Blount County, AL          52902.0
# ...        ...   ...                  ...              ...
# 3136     56039    WY     Teton County, WY          98837.0
# 3137     56041    WY     Uinta County, WY          70756.0
# 3138     56043    WY  Washakie County, WY          55122.0
# 3139     56045    WY    Weston County, WY          59410.0
# 3140      2063   NaN                  NaN              NaN
#
#       bach_deg_pct_14to18  Latitude   Longitude  population2019  Brewery_Count
# 0                    27.7  32.53638  -86.644490         55869.0            0.0
# 1                    31.3  30.65922  -87.746067        223234.0            3.0
# 2                    12.2  31.87067  -85.405456         24686.0            0.0
# 3                    11.5  33.01589  -87.127148         22394.0            0.0
# 4                    12.6  33.97745  -86.567246         57826.0            0.0
# ...                   ...       ...         ...             ...            ...
# 3136                 57.4  44.04932 -110.588102         23464.0            4.0
# 3137                 15.4  41.28473 -110.558947         20226.0            1.0
# 3138                 21.5  43.87883 -107.669052          7805.0            0.0
# 3139                 19.2  43.84621 -104.570020          6927.0            0.0
# 3140                  NaN       NaN         NaN             NaN            1.0
#
# [3141 rows x 9 columns]

# %%
merged_df.to_csv("countydemographics_withbrewerycount.csv")

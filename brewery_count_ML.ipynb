# %%
from sklearn import tree
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join("rg_proj2_resources/countydemographicsFINALPROJwithbrewcount.csv"))
df.head()
# Out:
#    fips_txt Stabr                 area_name  countbrewpub  countcontract  \
# 0      8111    CO       San Juan County, CO             2              0
# 1      2230    AK  Skagway Municipality, AK             2              0
# 2     35021    NM        Harding County, NM             0              0
# 3      8053    CO       Hinsdale County, CO             1              0
# 4      8091    CO          Ouray County, CO             3              0
#
#    countmicro  countregional  counttotal  countlargest  countbest  ...  \
# 0           0              0           2             0          0  ...
# 1           0              0           2             0          0  ...
# 2           1              0           1             0          0  ...
# 3           0              0           1             0          0  ...
# 4           1              0           4             0          0  ...
#
#    regionalper10000  breweriesTOTALper10000  largestboolean  bestboolean  \
# ...

# %%
df_sample = df.sample(frac=0.25)
df_sample
# Out:
#       fips_txt Stabr            area_name  countbrewpub  countcontract  \
# 579      51145    VA  Powhatan County, VA             1              0
# 175      30083    MT  Richland County, MT             1              0
# 1132     40131    OK    Rogers County, OK             0              0
# 918      42079    PA   Luzerne County, PA             1              1
# 2955     48455    TX   Trinity County, TX             0              0
# ...        ...   ...                  ...           ...            ...
# 1563     13225    GA     Peach County, GA             0              0
# 503      18129    IN     Posey County, IN             0              0
# 546      51067    VA  Franklin County, VA             0              0
# 2869     48241    TX    Jasper County, TX             0              0
# 2783     48001    TX  Anderson County, TX             0              0
#
#       countmicro  countregional  counttotal  countlargest  countbest  ...  \
# ...

# %%
target = df_sample["breweriesTOTALper10000"]
df_sample.columns
# Out:
# Index(['fips_txt', 'Stabr', 'area_name', 'countbrewpub', 'countcontract',
#        'countmicro', 'countregional', 'counttotal', 'countlargest',
#        'countbest', 'brewpubper10000', 'contractper10000', 'microper10000',
#        'regionalper10000', 'breweriesTOTALper10000', 'largestboolean',
#        'bestboolean', 'median_HHI_2019', 'bach_deg_pct_14to18', 'Latitude',
#        'Longitude', 'population2019', 'countyshort'],
#       dtype='object')

# %%
data = df_sample[['median_HHI_2019', 'bach_deg_pct_14to18','population2019']]
data.head()
# Out:
#       median_HHI_2019  bach_deg_pct_14to18  population2019
# 579             94293                 28.8           29652
# 175             69095                 19.0           10803
# 1132            67054                 24.3           92459
# 918             53439                 23.2          317417
# 2955            43788                 12.8           14651

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)
print(X_train)
print(X_test)
# Out:
#       median_HHI_2019  bach_deg_pct_14to18  population2019
# 2395            47254                 29.3           19572
# 1073            61847                 32.9           76745
# 637             81721                 41.5          162436
# 2051            48371                 14.5            8209
# 2700            70472                 31.3            3098
# ...               ...                  ...             ...
# 697             65841                 35.5           35856
# 91              39874                 17.0            7393
# 2279            50001                 21.9            1690
# 256            106892                 55.5           70465
# 2072            52692                 15.0            4991
#
# [588 rows x 3 columns]
#       median_HHI_2019  bach_deg_pct_14to18  population2019
# 2729            54319                 20.7           42208
# 2742            46176                 11.0           25178
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# -0.589350671844296

# %%
y_pred = rf.predict(X_test)
y_pred
# Out:
# array([0.12828758, 0.02638917, 0.07624547, 0.26248756, 0.01207249,
#        0.        , 0.5492365 , 0.35765287, 0.17835953, 0.08350446,
#        0.09217247, 0.23832607, 0.04353011, 0.80379489, 0.31767867,
#        0.02396433, 0.10105703, 0.04325739, 0.41784323, 0.12709698,
#        0.04460104, 0.06252192, 0.01640237, 0.18132842, 0.01045938,
#        0.06181934, 0.00981412, 0.12472364, 0.19635756, 0.1046085 ,
#        0.11985394, 0.23629151, 0.05006113, 0.03861159, 0.20027599,
#        0.67170802, 0.58388707, 0.1996896 , 0.27815367, 0.47127311,
#        0.00928656, 0.        , 0.02031063, 0.14738388, 0.43445125,
#        0.13065549, 0.43410447, 0.19153865, 0.11572493, 0.20057474,
#        0.12933506, 0.11025499, 0.05405259, 0.05034785, 0.51512462,
#        0.22169318, 0.262998  , 0.02953378, 0.        , 0.05825505,
#        0.10440708, 0.25834562, 0.01212562, 0.00617742, 0.24173107,
#        0.17657955, 0.01870436, 1.55923758, 0.        , 0.12501955,
# ...

# %%
import numpy as np
from sklearn.metrics import r2_score,mean_squared_error

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# 0.43631612909607886

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-1903024cf112> in <module>()
#       1 # The baseline predictions are the historical averages
# ----> 2 baseline_preds = X_train[:, feature_list.index('average')]
#       3 # Baseline errors, and display average baseline error
#       4 baseline_errors = abs(baseline_preds - test_labels)
#       5 print('Average baseline error: ', round(np.mean(baseline_errors), 2))
#
# NameError: name 'feature_list' is not defined

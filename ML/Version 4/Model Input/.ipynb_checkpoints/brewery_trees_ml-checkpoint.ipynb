# %%
from sklearn import tree
import pandas as pd
import os

# Inclusion of code for Permutational importance per dan
from sklearn.inspection import permutation_importance

# %%
df = pd.read_csv(os.path.join("data_best_final.csv"))
df.head(20)
# Out:
#     BestList  median_HHI_2019  bach_deg_pct_14to18  pop_density_per_mile  \
# 0      False            59871                59871            140.417818
# 1      False            47747                47747            187.507840
# 2      False            43047                43047            191.158356
# 3      False            44322                44322             47.896403
# 4      False            54127                54127            592.627754
# 5      False            48188                48188            138.878863
# 6      False            54160                54160            270.834979
# 7      False            68609                68609            465.209901
# 8      False            48913                48913            171.026541
# 9      False            49492                49492            336.097476
# 10     False            52711                52711            288.794219
# 11     False            54355                54355            206.579245
# 12     False            43670                43670             90.403032
# 13     False            77801                77801            277.352121
# 14     False            52307                52307            158.391684
# 15     False            45991                45991             80.285190
# 16      True            82512                82512            168.946367
# 17     False            74076                74076             13.197907
# 18     False            62548                62548              1.091176
# 19     False            53141                53141              0.285452
#
#     change_in_pop_decade  perc_female  perc_hispanic  unemployment_rate  \
# 0                 0.1835        0.515          0.047                2.7
# 1                -0.0437        0.520          0.041                3.5
# 2                -0.0211        0.516          0.041                3.3
# 3                -0.0310        0.509          0.031                3.3
# 4                 0.0002        0.527          0.041                2.9
# 5                 0.0002        0.520          0.029                3.3
# 6                 0.1477        0.509          0.037                2.7
# 7                 0.1022        0.511          0.052                2.5
# 8                 0.0388        0.507          0.147                2.5
# 9                 0.0005        0.525          0.030                3.7
# 10               -0.0127        0.530          0.037                3.1
# 11                0.0016        0.508          0.087                2.6
# 12                0.0865        0.521          0.058                2.9
# 13                0.1039        0.517          0.058                2.2
# 14                0.0702        0.519          0.040                2.7
# 15               -0.0551        0.512          0.026                3.3
# 16               -0.0133        0.491          0.094                5.1
# 17               -0.0076        0.462          0.082                5.4
# 18                0.0087        0.502          0.036                8.9
# 19               -0.0009        0.468          0.060               11.4
#
#     perc_age_25_39  brewery_per_1Mpeople
# 0           0.1730             13.438813
# 1           0.1924              8.802429
# 2           0.1814              9.778230
# 3           0.1716             19.370085
# 4           0.2124             13.665911
# 5           0.1756             21.568226
# 6           0.2040              6.077476
# 7           0.2063             26.816194
# 8           0.1837             10.333354
# 9           0.2026              9.680308
# 10          0.2095              4.415284
# 11          0.1842              8.355685
# 12          0.2164             17.252980
# 13          0.1882              4.593435
# 14          0.2105             14.329727
# 15          0.1752             31.485650
# 16          0.2482             41.666667
# 17          0.2576             30.976056
# 18          0.1628            395.256917
# 19          0.1457            465.549348

# %%
df["BestList"].value_counts()
# Out:
# False    1243
# True       41
# Name: BestList, dtype: int64

# %%
False_df = df[df["BestList"]==False]
False_df.head()
# Out:
#    BestList  median_HHI_2019  bach_deg_pct_14to18  pop_density_per_mile  \
# 0     False            59871                59871            140.417818
# 1     False            47747                47747            187.507840
# 2     False            43047                43047            191.158356
# 3     False            44322                44322             47.896403
# 4     False            54127                54127            592.627754
#
#    change_in_pop_decade  perc_female  perc_hispanic  unemployment_rate  \
# 0                0.1835        0.515          0.047                2.7
# 1               -0.0437        0.520          0.041                3.5
# 2               -0.0211        0.516          0.041                3.3
# 3               -0.0310        0.509          0.031                3.3
# 4                0.0002        0.527          0.041                2.9
#
#    perc_age_25_39  brewery_per_1Mpeople
# 0          0.1730             13.438813
# 1          0.1924              8.802429
# 2          0.1814              9.778230
# 3          0.1716             19.370085
# 4          0.2124             13.665911

# %%
True_df = df[df["BestList"]==True]
True_df.head()
# Out:
#     BestList  median_HHI_2019  bach_deg_pct_14to18  pop_density_per_mile  \
# 16      True            82512                82512            168.946367
# 49      True            58394                58394            133.938785
# 63      True            72721                72721           2473.975846
# 73      True            95761                95761           4016.975137
# 79      True            83576                83576            793.587741
#
#     change_in_pop_decade  perc_female  perc_hispanic  unemployment_rate  \
# 16               -0.0133        0.491          0.094                5.1
# 49               -0.0037        0.505          0.172                5.1
# 63                0.0220        0.507          0.486                4.4
# 73                0.0521        0.507          0.340                2.8
# 79                0.0728        0.497          0.341                3.2
#
#     perc_age_25_39  brewery_per_1Mpeople
# 16          0.2482             41.666667
# 49          0.1914             31.936346
# 63          0.2348             12.252086
# 73          0.2112             17.319060
# 79          0.2373             47.628605

# %%
Final_df = pd.concat([True_df,False_df.sample(n=len(True_df))] ,ignore_index=True,copy=True ) 
Final_df
# Out:
#     BestList  median_HHI_2019  bach_deg_pct_14to18  pop_density_per_mile  \
# 0       True            82512                82512            168.946367
# 1       True            58394                58394            133.938785
# 2       True            72721                72721           2473.975846
# 3       True            95761                95761           4016.975137
# 4       True            83576                83576            793.587741
# ..       ...              ...                  ...                   ...
# 77     False            68404                68404             16.821971
# 78     False            41327                41327             61.148547
# 79     False            57789                57789             47.674379
# 80     False            67315                67315             59.199334
# 81     False            79739                79739            138.713828
#
#     change_in_pop_decade  perc_female  perc_hispanic  unemployment_rate  \
# 0                -0.0133        0.491          0.094                5.1
# 1                -0.0037        0.505          0.172                5.1
# 2                 0.0220        0.507          0.486                4.4
# 3                 0.0521        0.507          0.340                2.8
# 4                 0.0728        0.497          0.341                3.2
# ..                   ...          ...            ...                ...
# 77                0.1202        0.501          0.197                2.4
# 78               -0.0074        0.514          0.022                4.7
# 79                0.0566        0.519          0.274                3.0
# 80               -0.0145        0.502          0.013                3.4
# 81                0.1125        0.501          0.116                2.6
#
#     perc_age_25_39  brewery_per_1Mpeople
# 0           0.2482             41.666667
# 1           0.1914             31.936346
# 2           0.2348             12.252086
# 3           0.2112             17.319060
# 4           0.2373             47.628605
# ..             ...                   ...
# 77          0.1390            167.630542
# 78          0.1851             23.541598
# 79          0.1546             38.022814
# 80          0.1626             43.940592
# 81          0.1855             38.019200
#
# [82 rows x 10 columns]

# %%
Final_df["BestList"].value_counts()
# Out:
# True     41
# False    41
# Name: BestList, dtype: int64

# %%
target = Final_df["BestList"]
target_names = ["no", "yes"]

# %%
data = Final_df.drop("BestList", axis=1)
feature_names = data.columns
data.head()
# Out:
#    median_HHI_2019  bach_deg_pct_14to18  pop_density_per_mile  \
# 0            82512                82512            168.946367
# 1            58394                58394            133.938785
# 2            72721                72721           2473.975846
# 3            95761                95761           4016.975137
# 4            83576                83576            793.587741
#
#    change_in_pop_decade  perc_female  perc_hispanic  unemployment_rate  \
# 0               -0.0133        0.491          0.094                5.1
# 1               -0.0037        0.505          0.172                5.1
# 2                0.0220        0.507          0.486                4.4
# 3                0.0521        0.507          0.340                2.8
# 4                0.0728        0.497          0.341                3.2
#
#    perc_age_25_39  brewery_per_1Mpeople
# 0          0.2482             41.666667
# 1          0.1914             31.936346
# 2          0.2348             12.252086
# 3          0.2112             17.319060
# 4          0.2373             47.628605

# %%
data.fillna(data.mean(), inplace=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.7142857142857143

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.8095238095238095

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.2020788794967094, 'pop_density_per_mile'),
#  (0.16885281677437955, 'median_HHI_2019'),
#  (0.15289220439275245, 'bach_deg_pct_14to18'),
#  (0.09046592982456697, 'brewery_per_1Mpeople'),
#  (0.08982280240536841, 'perc_female'),
#  (0.08931653156933216, 'change_in_pop_decade'),
#  (0.07513903125386823, 'perc_age_25_39'),
#  (0.07083171428363101, 'perc_hispanic'),
#  (0.06060008999939179, 'unemployment_rate')]

# %%
from sklearn.metrics import classification_report

# %%
y_predict = rf.predict(X_test)

# %%
print (classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.70      0.88      0.78         8
#         True       0.91      0.77      0.83        13
#
#     accuracy                           0.81        21
#    macro avg       0.80      0.82      0.81        21
# weighted avg       0.83      0.81      0.81        21

# %% [markdown]
# ## Comparision of Calibration of Classifiers

# %%
print(__doc__)

# Author: Jan Hendrik Metzen <jhm@informatik.uni-bremen.de>
# License: BSD Style.

import numpy as np
# np.random.seed(0)

import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.calibration import calibration_curve

# X, y = datasets.make_classification(n_samples=100000, n_features=20,
#                                     n_informative=2, n_redundant=2)

# train_samples = 100  # Samples used for training the models

# X_train = X[:train_samples]
# X_test = X[train_samples:]
# y_train = y[:train_samples]
# y_test = y[train_samples:]

# Create classifiers
lr = LogisticRegression()
gnb = GaussianNB()
svc = LinearSVC(C=1.0)
rfc = RandomForestClassifier()


# #############################################################################
# Plot calibration plots

plt.figure(figsize=(10, 10))
ax1 = plt.subplot2grid((3, 1), (0, 0), rowspan=2)
ax2 = plt.subplot2grid((3, 1), (2, 0))

ax1.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
for clf, name in [(lr, 'Logistic'),
                  (gnb, 'Naive Bayes'),
                  (svc, 'Support Vector Classification'),
                  (rfc, 'Random Forest')]:
    clf.fit(X_train, y_train)
    if hasattr(clf, "predict_proba"):
        prob_pos = clf.predict_proba(X_test)[:, 1]
    else:  # use decision function
        prob_pos = clf.decision_function(X_test)
        prob_pos = \
            (prob_pos - prob_pos.min()) / (prob_pos.max() - prob_pos.min())
    fraction_of_positives, mean_predicted_value = \
        calibration_curve(y_test, prob_pos, n_bins=10)

    ax1.plot(mean_predicted_value, fraction_of_positives, "s-",
             label="%s" % (name, ))

    ax2.hist(prob_pos, range=(0, 1), bins=10, label=name,
             histtype="step", lw=2)

ax1.set_ylabel("Fraction of positives")
ax1.set_ylim([-0.05, 1.05])
ax1.legend(loc="lower right")
ax1.set_title('Calibration plots  (reliability curve)')

ax2.set_xlabel("Mean predicted value")
ax2.set_ylabel("Count")
ax2.legend(loc="upper center", ncol=2)

plt.tight_layout()
plt.show()
# Out:
# Automatically created module for IPython interactive environment
# C:\Users\zach-\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %% [markdown]
# # Permutation Importance Model

# %%
# rf is the random forest model, for X you can use X or X_train, and the corresponding y (/y_train)
result = permutation_importance(rf, X_train, y_train, random_state=0)

# %%
# then you can use the importances_mean like your importances from your model
sorted(zip(result.importances_mean, feature_names), reverse=True)
# Out:
# [(0.18688524590163935, 'pop_density_per_mile'),
#  (0.02622950819672134, 'brewery_per_1Mpeople'),
#  (0.022950819672131174, 'change_in_pop_decade'),
#  (0.019672131147541006, 'perc_hispanic'),
#  (0.01311475409836067, 'median_HHI_2019'),
#  (0.009836065573770503, 'perc_female'),
#  (0.009836065573770503, 'perc_age_25_39'),
#  (0.009836065573770503, 'bach_deg_pct_14to18'),
#  (0.006557377049180335, 'unemployment_rate')]

# %% [markdown]
# ## Prediction Output

# %%
data.to_numpy(dtype=None,copy=False)
# Out:
# array([[ 8.25120000e+04,  8.25120000e+04,  1.68946367e+02,
#         -1.33000000e-02,  4.91000000e-01,  9.40000000e-02,
#          5.10000000e+00,  2.48200000e-01,  4.16666667e+01],
#        [ 5.83940000e+04,  5.83940000e+04,  1.33938785e+02,
#         -3.70000000e-03,  5.05000000e-01,  1.72000000e-01,
#          5.10000000e+00,  1.91400000e-01,  3.19363463e+01],
#        [ 7.27210000e+04,  7.27210000e+04,  2.47397585e+03,
#          2.20000000e-02,  5.07000000e-01,  4.86000000e-01,
#          4.40000000e+00,  2.34800000e-01,  1.22520858e+01],
#        [ 9.57610000e+04,  9.57610000e+04,  4.01697514e+03,
#          5.21000000e-02,  5.07000000e-01,  3.40000000e-01,
#          2.80000000e+00,  2.11200000e-01,  1.73190599e+01],
#        [ 8.35760000e+04,  8.35760000e+04,  7.93587741e+02,
#          7.28000000e-02,  4.97000000e-01,  3.41000000e-01,
#          3.20000000e+00,  2.37300000e-01,  4.76286047e+01],
#        [ 1.21795000e+05,  1.21795000e+05,  1.88071811e+04,
#          8.66000000e-02,  4.90000000e-01,  1.52000000e-01,
#          2.20000000e+00,  3.25600000e-01,  4.19715750e+01],
#        [ 7.45300000e+04,  7.45300000e+04,  1.63248674e+02,
#          5.06000000e-02,  5.00000000e-01,  4.60000000e-01,
#          3.70000000e+00,  1.95600000e-01,  4.92722268e+01],
#        [ 8.57700000e+04,  8.57700000e+04,  6.13727340e+02,
#          3.96000000e-02,  5.05000000e-01,  3.40000000e-01,
#          4.70000000e+00,  1.80200000e-01,  4.39217753e+01],
#        [ 8.70840000e+04,  8.70840000e+04,  3.13695030e+02,
#          2.12000000e-02,  5.12000000e-01,  2.73000000e-01,
#          2.70000000e+00,  1.93100000e-01,  6.47332988e+01],
#        [ 8.83410000e+04,  8.83410000e+04,  4.49127000e+02,
#          9.70000000e-02,  4.96000000e-01,  1.40000000e-01,
#          2.40000000e+00,  2.05000000e-01,  1.22625661e+02],
#        [ 6.11330000e+04,  6.11330000e+04,  1.44280318e+03,
#          1.64900000e-01,  5.11000000e-01,  2.97000000e-01,
#          3.10000000e+00,  2.25400000e-01,  1.15491641e+01],
#        [ 5.49910000e+04,  5.49910000e+04,  1.43168946e+03,
#          8.12000000e-02,  5.14000000e-01,  6.94000000e-01,
#          2.40000000e+00,  2.09000000e-01,  6.62510030e+00],
#        [ 6.66210000e+04,  6.66210000e+04,  7.59873142e+02,
#          1.18000000e-01,  5.15000000e-01,  2.34000000e-01,
#          3.30000000e+00,  1.77000000e-01,  1.00215798e+01],
#        [ 5.67080000e+04,  5.67080000e+04,  3.56099182e+03,
#          6.00000000e-02,  5.20000000e-01,  1.02000000e-01,
#          3.00000000e+00,  1.78700000e-01,  3.79488736e+01],
#        [ 6.93750000e+04,  6.93750000e+04,  5.44810256e+03,
#         -8.60000000e-03,  5.14000000e-01,  2.56000000e-01,
#          3.80000000e+00,  2.35400000e-01,  1.65041077e+01],
#        [ 5.72800000e+04,  5.72800000e+04,  9.73007910e+02,
#         -2.17000000e-02,  5.16000000e-01,  1.96000000e-01,
#          4.90000000e+00,  1.88800000e-01,  2.47171432e+01],
#        [ 6.54820000e+04,  6.54820000e+04,  2.89780074e+01,
#         -5.33000000e-02,  5.02000000e-01,  2.40000000e-02,
#          2.90000000e+00,  1.39800000e-01,  1.00045020e+02],
#        [ 7.52540000e+04,  7.52540000e+04,  3.53195066e+02,
#          4.52000000e-02,  5.16000000e-01,  2.20000000e-02,
#          2.40000000e+00,  2.03900000e-01,  1.15253065e+02],
#        [ 1.06543000e+05,  1.06543000e+05,  1.97073306e+03,
#          6.74000000e-02,  5.10000000e-01,  8.30000000e-02,
#          2.30000000e+00,  2.25700000e-01,  1.86138975e+01],
#        [ 1.06851000e+05,  1.06851000e+05,  1.78431224e+03,
#          5.08000000e-02,  5.19000000e-01,  5.00000000e-02,
#          2.50000000e+00,  1.95600000e-01,  1.41487744e+01],
#        [ 7.58430000e+04,  7.58430000e+04,  1.38237610e+04,
#          1.01900000e-01,  5.17000000e-01,  2.33000000e-01,
#          2.60000000e+00,  3.08200000e-01,  1.74149497e+01],
#        [ 7.77950000e+04,  7.77950000e+04,  5.49800433e+02,
#          3.86000000e-02,  5.07000000e-01,  1.22000000e-01,
#          3.10000000e+00,  1.93600000e-01,  2.76900925e+01],
#        [ 6.65600000e+04,  6.65600000e+04,  7.75673359e+02,
#          8.27000000e-02,  5.07000000e-01,  1.08000000e-01,
#          2.90000000e+00,  2.28300000e-01,  6.08869709e+01],
#        [ 6.50510000e+04,  6.50510000e+04,  1.82372716e+03,
#          3.78000000e-02,  5.13000000e-01,  2.80000000e-02,
#          4.20000000e+00,  1.97500000e-01,  1.25862156e+01],
#        [ 5.07530000e+04,  5.07530000e+04,  2.85803000e+03,
#         -4.07000000e-02,  5.18000000e-01,  6.10000000e-02,
#          5.10000000e+00,  2.04400000e-01,  1.48627227e+01],
#        [ 8.23230000e+04,  8.23230000e+04,  2.28660329e+03,
#          8.96000000e-02,  5.05000000e-01,  7.00000000e-02,
#          2.80000000e+00,  2.45800000e-01,  3.39694575e+01],
#        [ 5.79070000e+04,  5.79070000e+04,  1.16303589e+03,
#          4.10000000e-02,  5.16000000e-01,  9.20000000e-02,
#          3.70000000e+00,  2.25800000e-01,  3.12939627e+01],
#        [ 7.01610000e+04,  7.01610000e+04,  1.95786727e+03,
#         -4.80000000e-03,  5.25000000e-01,  3.00000000e-02,
#          3.10000000e+00,  1.93400000e-01,  1.00582878e+01],
#        [ 6.65010000e+04,  6.65010000e+04,  3.61486528e+04,
#          2.16000000e-02,  5.26000000e-01,  1.89000000e-01,
#          4.10000000e+00,  2.59700000e-01,  7.42215623e+00],
#        [ 5.24140000e+04,  5.24140000e+04,  5.93920335e+01,
#         -4.65000000e-02,  5.15000000e-01,  3.80000000e-02,
#          4.20000000e+00,  1.50900000e-01,  6.72348007e+01],
#        [ 7.06880000e+04,  7.06880000e+04,  2.43265571e+02,
#         -4.50000000e-03,  5.06000000e-01,  5.20000000e-02,
#          3.80000000e+00,  2.06500000e-01,  3.15032070e+01],
#        [ 5.54480000e+04,  5.54480000e+04,  3.97749561e+02,
#          8.76000000e-02,  5.21000000e-01,  6.80000000e-02,
#          3.00000000e+00,  2.09100000e-01,  1.26344323e+02],
#        [ 6.16510000e+04,  6.16510000e+04,  3.14733507e+02,
#          9.09000000e-02,  5.20000000e-01,  1.03000000e-01,
#          3.30000000e+00,  1.59100000e-01,  5.10999259e+01],
#        [ 5.77530000e+04,  5.77530000e+04,  1.31075862e+03,
#         -1.40000000e-03,  5.15000000e-01,  2.30000000e-02,
#          4.30000000e+00,  1.95500000e-01,  3.51193040e+01],
#        [ 7.18800000e+04,  7.18800000e+04,  6.55002707e+01,
#          2.02100000e-01,  5.05000000e-01,  8.30000000e-02,
#          3.90000000e+00,  2.01900000e-01,  1.26459341e+02],
#        [ 7.24690000e+04,  7.24690000e+04,  1.88467576e+03,
#          9.54000000e-02,  5.05000000e-01,  1.20000000e-01,
#          3.30000000e+00,  2.77200000e-01,  9.84185371e+01],
#        [ 5.22980000e+04,  5.22980000e+04,  2.45206697e+01,
#          6.61000000e-02,  4.95000000e-01,  1.05000000e-01,
#          3.90000000e+00,  1.64300000e-01,  1.47950880e+02],
#        [ 9.23400000e+04,  9.23400000e+04,  1.72017845e+03,
#          3.74000000e-02,  5.14000000e-01,  5.40000000e-02,
#          3.50000000e+00,  1.91300000e-01,  2.16628656e+01],
#        [ 4.88260000e+04,  4.88260000e+04,  3.89993480e+01,
#         -7.20000000e-03,  4.99000000e-01,  1.70000000e-02,
#          4.20000000e+00,  1.67800000e-01,  3.69863520e+01],
#        [ 7.41780000e+04,  7.41780000e+04,  6.17495870e+01,
#          8.10000000e-03,  5.03000000e-01,  1.80000000e-02,
#          2.50000000e+00,  1.50500000e-01,  2.99230976e+01],
#        [ 1.02338000e+05,  1.02338000e+05,  1.06486018e+03,
#          1.42700000e-01,  4.97000000e-01,  9.90000000e-02,
#          2.80000000e+00,  2.67100000e-01,  4.52773504e+01],
#        [ 4.75990000e+04,  4.75990000e+04,  1.05166198e+02,
#          4.09000000e-02,  5.04000000e-01,  5.20000000e-02,
#          5.70000000e+00,  1.73200000e-01,  3.01504508e+01],
#        [ 5.66950000e+04,  5.66950000e+04,  2.20051939e+01,
#         -2.69000000e-02,  5.07000000e-01,  4.50000000e-02,
#          2.70000000e+00,  1.69900000e-01,  1.04624398e+02],
#        [ 5.86600000e+04,  5.86600000e+04,  1.69170551e+01,
#          1.60000000e-03,  4.94000000e-01,  1.60000000e-02,
#          6.00000000e+00,  1.52900000e-01,  2.21582096e+01],
#        [ 5.80170000e+04,  5.80170000e+04,  2.03195689e+02,
#          6.64000000e-02,  5.30000000e-01,  6.80000000e-02,
#          3.30000000e+00,  1.76700000e-01,  1.17244290e+01],
#        [ 6.42190000e+04,  6.42190000e+04,  8.06188379e+01,
#         -1.94000000e-02,  5.05000000e-01,  3.10000000e-02,
#          2.90000000e+00,  1.67700000e-01,  1.98082561e+01],
#        [ 4.79810000e+04,  4.79810000e+04,  7.31980396e+00,
#         -2.45000000e-02,  5.01000000e-01,  3.40000000e-02,
#          3.20000000e+00,  1.55800000e-01,  2.40500240e+02],
#        [ 5.43770000e+04,  5.43770000e+04,  1.34470967e+02,
#         -3.59000000e-02,  5.19000000e-01,  3.00000000e-02,
#          4.80000000e+00,  1.62200000e-01,  4.61794224e+01],
#        [ 4.16560000e+04,  4.16560000e+04,  5.53011876e+02,
#          1.08100000e-01,  5.10000000e-01,  9.25000000e-01,
#          6.20000000e+00,  1.98500000e-01,  4.60454446e+00],
#        [ 4.81020000e+04,  4.81020000e+04,  4.33881315e+01,
#          3.69000000e-02,  4.87000000e-01,  8.50000000e-01,
#          1.83000000e+01,  2.14900000e-01,  1.10366140e+01],
#        [ 6.65910000e+04,  6.65910000e+04,  3.67485487e+02,
#         -2.40000000e-02,  5.13000000e-01,  3.40000000e-02,
#          3.90000000e+00,  1.97200000e-01,  1.14083189e+01],
#        [ 5.67390000e+04,  5.67390000e+04,  4.71934879e+02,
#          5.56000000e-02,  5.11000000e-01,  5.20000000e-02,
#          3.30000000e+00,  1.98800000e-01,  7.16802608e+01],
#        [ 5.89430000e+04,  5.89430000e+04,  7.10309810e+01,
#         -6.90000000e-03,  5.01000000e-01,  2.30000000e-02,
#          3.30000000e+00,  1.92200000e-01,  2.94048459e+01],
#        [ 6.33510000e+04,  6.33510000e+04,  5.89621172e+01,
#         -5.57000000e-02,  5.13000000e-01,  1.40000000e-02,
#          4.40000000e+00,  1.65500000e-01,  4.59284435e+01],
#        [ 4.36180000e+04,  4.36180000e+04,  5.73064661e+01,
#          4.11000000e-02,  5.10000000e-01,  6.88000000e-01,
#          5.70000000e+00,  1.91300000e-01,  2.29152822e+01],
#        [ 5.18690000e+04,  5.18690000e+04,  1.50147620e+00,
#          3.70000000e-03,  4.96000000e-01,  2.80000000e-02,
#          3.20000000e+00,  1.60800000e-01,  1.35208221e+02],
#        [ 6.86090000e+04,  6.86090000e+04,  4.65209901e+02,
#          1.02200000e-01,  5.11000000e-01,  5.20000000e-02,
#          2.50000000e+00,  2.06300000e-01,  2.68161938e+01],
#        [ 5.57450000e+04,  5.57450000e+04,  7.41675436e+02,
#          1.61100000e-01,  5.14000000e-01,  1.65000000e-01,
#          3.50000000e+00,  1.74100000e-01,  1.08313611e+01],
#        [ 4.52350000e+04,  4.52350000e+04,  5.53371264e+01,
#         -5.80000000e-02,  5.21000000e-01,  9.50000000e-02,
#          4.40000000e+00,  1.51000000e-01,  8.53970965e+01],
#        [ 4.89430000e+04,  4.89430000e+04,  3.07049393e+01,
#         -3.15000000e-02,  4.49000000e-01,  3.60000000e-02,
#          4.90000000e+00,  2.09000000e-01,  7.99648155e+01],
#        [ 6.43990000e+04,  6.43990000e+04,  6.66830548e+02,
#          1.38100000e-01,  5.15000000e-01,  9.50000000e-02,
#          2.40000000e+00,  2.07100000e-01,  2.29207972e+01],
#        [ 7.77380000e+04,  7.77380000e+04,  1.45567535e+04,
#          5.67000000e-02,  5.02000000e-01,  4.27000000e-01,
#          3.30000000e+00,  3.01200000e-01,  2.97445980e+00],
#        [ 4.55340000e+04,  4.55340000e+04,  2.32937832e+03,
#          2.13000000e-02,  5.23000000e-01,  6.70000000e-02,
#          3.00000000e+00,  2.21400000e-01,  2.01728816e+01],
#        [ 6.03160000e+04,  6.03160000e+04,  9.25421328e+02,
#          8.10000000e-02,  5.14000000e-01,  4.60000000e-02,
#          2.90000000e+00,  2.03700000e-01,  3.40198974e+01],
#        [ 3.90300000e+04,  3.90300000e+04,  1.26832261e+01,
#         -1.75500000e-01,  4.93000000e-01,  1.80000000e-02,
#          5.20000000e+00,  1.46000000e-01,  7.15563506e+01],
#        [ 6.73980000e+04,  6.73980000e+04,  1.08694807e+02,
#          6.65000000e-02,  5.02000000e-01,  5.44000000e-01,
#          3.80000000e+00,  2.23000000e-01,  1.14674428e+01],
#        [ 5.60010000e+04,  5.60010000e+04,  2.25905203e+02,
#         -1.10000000e-02,  4.89000000e-01,  3.60000000e-02,
#          3.80000000e+00,  1.87900000e-01,  3.15437512e+01],
#        [ 6.72420000e+04,  6.72420000e+04,  9.65131918e+01,
#          6.88000000e-02,  5.09000000e-01,  7.40000000e-02,
#          2.40000000e+00,  1.78300000e-01,  1.22028603e+01],
#        [ 6.02490000e+04,  6.02490000e+04,  4.63235820e+01,
#          4.86000000e-02,  5.05000000e-01,  1.48000000e-01,
#          3.40000000e+00,  1.97000000e-01,  3.89079826e+01],
#        [ 4.96190000e+04,  4.96190000e+04,  3.62512500e+02,
#          1.00800000e-01,  5.11000000e-01,  5.60000000e-02,
#          5.20000000e+00,  2.07200000e-01,  9.61168781e+00],
#        [ 6.02350000e+04,  6.02350000e+04,  4.89753290e+01,
#         -7.51000000e-02,  4.98000000e-01,  1.80000000e-02,
#          4.30000000e+00,  1.53600000e-01,  4.95933347e+01],
#        [ 5.93460000e+04,  5.93460000e+04,  3.94636880e+01,
#          3.02000000e-02,  4.89000000e-01,  1.03000000e-01,
#          7.10000000e+00,  1.76900000e-01,  3.99674931e+01],
#        [ 7.88010000e+04,  7.88010000e+04,  2.34566287e+02,
#          2.11700000e-01,  5.05000000e-01,  3.85000000e-01,
#          2.90000000e+00,  2.03700000e-01,  1.19870300e+01],
#        [ 3.76780000e+04,  3.76780000e+04,  1.28809652e+03,
#         -6.40000000e-02,  5.28000000e-01,  2.50000000e-02,
#          3.80000000e+00,  1.93700000e-01,  1.19317504e+02],
#        [ 6.21080000e+04,  6.21080000e+04,  2.25597293e+02,
#         -1.40000000e-03,  4.96000000e-01,  6.70000000e-02,
#          2.70000000e+00,  1.79500000e-01,  3.46800763e+01],
#        [ 7.28180000e+04,  7.28180000e+04,  1.36632241e+02,
#          1.72800000e-01,  5.09000000e-01,  4.70000000e-02,
#          2.90000000e+00,  1.72400000e-01,  4.51339915e+01],
#        [ 4.46190000e+04,  4.46190000e+04,  1.50475431e+03,
#          7.18000000e-02,  5.21000000e-01,  8.70000000e-02,
#          2.90000000e+00,  2.08100000e-01,  4.41891295e+01],
#        [ 6.84040000e+04,  6.84040000e+04,  1.68219713e+01,
#          1.20200000e-01,  5.01000000e-01,  1.97000000e-01,
#          2.40000000e+00,  1.39000000e-01,  1.67630542e+02],
#        [ 4.13270000e+04,  4.13270000e+04,  6.11485470e+01,
#         -7.40000000e-03,  5.14000000e-01,  2.20000000e-02,
#          4.70000000e+00,  1.85100000e-01,  2.35415980e+01],
#        [ 5.77890000e+04,  5.77890000e+04,  4.76743786e+01,
#          5.66000000e-02,  5.19000000e-01,  2.74000000e-01,
#          3.00000000e+00,  1.54600000e-01,  3.80228137e+01],
#        [ 6.73150000e+04,  6.73150000e+04,  5.91993341e+01,
#         -1.45000000e-02,  5.02000000e-01,  1.30000000e-02,
#          3.40000000e+00,  1.62600000e-01,  4.39405923e+01],
#        [ 7.97390000e+04,  7.97390000e+04,  1.38713828e+02,
#          1.12500000e-01,  5.01000000e-01,  1.16000000e-01,
#          2.60000000e+00,  1.85500000e-01,  3.80191997e+01]])

# %%
y_predict = rf.predict(data)
y_predict
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False])

# %%
## rf.predict on the array that we build to predict.
